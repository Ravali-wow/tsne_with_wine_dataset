# %%
##reference:https://www.analyticsvidhya.com/blog/2017/01/t-sne-implementation-r-python/
## importing the required packages
from time import time
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import offsetbox
from sklearn import (manifold, datasets, decomposition, ensemble,
             discriminant_analysis, random_projection)
## Loading and curating the data
d = datasets.load_wine()
X = d.data
y = d.target
n_samples, n_features = X.shape
n_neighbors = 20
## Function to Scale and visualize the embedding vectors


      #----------------------------------------------------------------------
## Plot images of the digits
## Computing t-SNE
print("Computing t-SNE embedding")
tsne2 = manifold.TSNE(n_components=2,init='pca', random_state=0)
t0 = time()
X_tsne2 = tsne2.fit_transform(X)
plot_embedding(X_tsne2,
               "t-SNE embedding (time %.2fs)" %
               (time() - t0))
tsne1 = manifold.TSNE(n_components=2, random_state=0)
t0 = time()
X_tsne1 = tsne1.fit_transform(X)
plot_embedding(X_tsne1,
               "t-SNE embedding (time %.2fs)" %
               (time() - t0))
# Out:
# Computing t-SNE embedding
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/__init__.py in __getattr__(self, key)
#     104         try:
# --> 105             return self[key]
#     106         except KeyError:
#
# KeyError: 'images'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-cb80505aabfb> in <module>()
#      23 plot_embedding(X_tsne2,
#      24                "t-SNE embedding (time %.2fs)" %
# ---> 25                (time() - t0))
#      26 tsne1 = manifold.TSNE(n_components=2, random_state=0)
#      27 t0 = time()
#
# <ipython-input-15-d17a93c70114> in plot_embedding(X, title)
#      31             shown_images = np.r_[shown_images, [X[i]]]
#      32             imagebox = offsetbox.AnnotationBbox(
# ---> 33             offsetbox.OffsetImage(d.images[i], cmap=plt.cm.gray_r),
#      34                 X[i])
#      35             ax.add_artist(imagebox)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/__init__.py in __getattr__(self, key)
#     105             return self[key]
#     106         except KeyError:
# --> 107             raise AttributeError(key)
#     108
#     109     def __setstate__(self, state):
#
# AttributeError: images
